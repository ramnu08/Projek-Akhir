# %%
import pandas as pd
import numpy as np
import pickle
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import Perceptron
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# %%
data = pd.read_excel('Pumpkin_Seeds_Dataset.xlsx')
data_fruit = pd.read_excel('fruit.xlsx')
data_fish = pd.read_csv('fish_data.csv')
data_fruit
# Out:
#       diameter  weight  red  green  blue        name
# 0         2.96   86.76  172     85     2      orange
# 1         3.91   88.05  166     78     3      orange
# 2         4.42   95.17  156     81     2      orange
# 3         4.47   95.60  163     81     4      orange
# 4         4.48   95.76  161     72     9      orange
# ...        ...     ...  ...    ...   ...         ...
# 9995     15.35  253.89  149     77    20  grapefruit
# 9996     15.41  254.67  148     68     7  grapefruit
# 9997     15.59  256.50  168     82    20  grapefruit
# 9998     15.92  260.14  142     72    11  grapefruit
# 9999     16.45  261.51  152     74     2  grapefruit
#
# [10000 rows x 6 columns]

# %%
data_fruit.shape
# Out:
# (10000, 6)

# %%
data_fruit.name.value_counts()
# Out:
# name
# orange        5000
# grapefruit    5000
# Name: count, dtype: int64

# %%
data_fruit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   diameter  10000 non-null  float64
#  1   weight    10000 non-null  float64
#  2   red       10000 non-null  int64
#  3   green     10000 non-null  int64
#  4   blue      10000 non-null  int64
#  5   name      10000 non-null  object
# dtypes: float64(2), int64(3), object(1)
# memory usage: 468.9+ KB

# %%
data_fruit.isnull().sum()
# Out:
# diameter    0
# weight      0
# red         0
# green       0
# blue        0
# name        0
# dtype: int64

# %%
x = data_fruit.drop(columns=['name'])
y = data_fruit['name']

#xbu = data_fruit.drop(columns=['name'])
#ybu = data_fruit['name']

#xfi = data_fish.drop(columns=['species'])
#yfi = data_fish['species']

x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=0.2, random_state=42)

#x_train_bu, x_test_bu, y_train_bu, y_test_bu = train_test_split(xbu,ybu, test_size=0.2, random_state=42)

#x_train_fi, x_test_fi, y_train_fi, y_test_fi = train_test_split(xfi,yfi, test_size=0.2, random_state=42)

# %%
clf = Perceptron(max_iter=100, tol=0.5, random_state=30)
clf.fit(x_train,y_train)
# Out:
# Perceptron(max_iter=100, random_state=30, tol=0.5)

# %%
fw = open('fruit_perceptron.pkl' , 'wb')
md = pickle.dump(clf , fw)

# %%
pred = clf.predict(x_test)
pred
# Out:
# array(['Anabas testudineus', 'Setipinna taty', 'Setipinna taty',
#        'Sillaginopsis panijus', 'Anabas testudineus', 'Setipinna taty',
#        'Setipinna taty', 'Sillaginopsis panijus', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Sillaginopsis panijus', 'Coilia dussumieri',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Pethia conchonius', 'Coilia dussumieri',
#        'Pethia conchonius', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Anabas testudineus', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Anabas testudineus', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Sillaginopsis panijus', 'Sillaginopsis panijus',
#        'Pethia conchonius', 'Setipinna taty', 'Pethia conchonius',
#        'Setipinna taty', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Setipinna taty', 'Anabas testudineus',
#        'Pethia conchonius', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Pethia conchonius',
#        'Pethia conchonius', 'Sillaginopsis panijus', 'Anabas testudineus',
#        'Anabas testudineus', 'Setipinna taty', 'Anabas testudineus',
#        'Setipinna taty', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Pethia conchonius', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Anabas testudineus', 'Setipinna taty', 'Setipinna taty',
#        'Pethia conchonius', 'Anabas testudineus', 'Setipinna taty',
#        'Setipinna taty', 'Sillaginopsis panijus', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Anabas testudineus', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Sillaginopsis panijus', 'Setipinna taty',
#        'Pethia conchonius', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Sillaginopsis panijus', 'Pethia conchonius', 'Pethia conchonius',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Sillaginopsis panijus', 'Anabas testudineus',
#        'Anabas testudineus', 'Anabas testudineus', 'Setipinna taty',
#        'Setipinna taty', 'Coilia dussumieri', 'Setipinna taty',
#        'Setipinna taty', 'Sillaginopsis panijus', 'Setipinna taty',
#        'Setipinna taty', 'Pethia conchonius', 'Anabas testudineus',
#        'Setipinna taty', 'Setipinna taty', 'Anabas testudineus',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Anabas testudineus', 'Anabas testudineus',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Sillaginopsis panijus', 'Setipinna taty', 'Setipinna taty',
#        'Pethia conchonius', 'Pethia conchonius', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Sillaginopsis panijus', 'Setipinna taty',
#        'Setipinna taty', 'Pethia conchonius', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Anabas testudineus', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Pethia conchonius', 'Pethia conchonius',
#        'Pethia conchonius', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Pethia conchonius', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Sillaginopsis panijus', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Anabas testudineus',
#        'Sillaginopsis panijus', 'Pethia conchonius', 'Setipinna taty',
#        'Pethia conchonius', 'Setipinna taty', 'Anabas testudineus',
#        'Setipinna taty', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Anabas testudineus', 'Pethia conchonius', 'Setipinna taty',
#        'Pethia conchonius', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Coilia dussumieri', 'Anabas testudineus', 'Pethia conchonius',
#        'Setipinna taty', 'Anabas testudineus', 'Sillaginopsis panijus',
#        'Coilia dussumieri', 'Sillaginopsis panijus', 'Setipinna taty',
#        'Setipinna taty', 'Pethia conchonius', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Pethia conchonius', 'Coilia dussumieri', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Anabas testudineus', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Pethia conchonius', 'Coilia dussumieri', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Sillaginopsis panijus', 'Setipinna taty',
#        'Setipinna taty', 'Coilia dussumieri', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Pethia conchonius',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Pethia conchonius', 'Pethia conchonius', 'Setipinna taty',
#        'Sillaginopsis panijus', 'Anabas testudineus', 'Setipinna taty',
#        'Setipinna taty', 'Pethia conchonius', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Pethia conchonius', 'Anabas testudineus',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Sillaginopsis panijus', 'Setipinna taty', 'Pethia conchonius',
#        'Setipinna taty', 'Pethia conchonius', 'Setipinna taty',
#        'Setipinna taty', 'Pethia conchonius', 'Setipinna taty',
#        'Setipinna taty', 'Sillaginopsis panijus', 'Setipinna taty',
#        'Sillaginopsis panijus', 'Setipinna taty', 'Coilia dussumieri',
#        'Setipinna taty', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Anabas testudineus', 'Sillaginopsis panijus', 'Pethia conchonius',
#        'Setipinna taty', 'Coilia dussumieri', 'Setipinna taty',
#        'Sillaginopsis panijus', 'Anabas testudineus',
#        'Sillaginopsis panijus', 'Setipinna taty', 'Anabas testudineus',
#        'Anabas testudineus', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Sillaginopsis panijus', 'Setipinna taty',
#        'Sillaginopsis panijus', 'Setipinna taty', 'Pethia conchonius',
#        'Setipinna taty', 'Sillaginopsis panijus', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Coilia dussumieri',
#        'Sillaginopsis panijus', 'Coilia dussumieri', 'Setipinna taty',
#        'Anabas testudineus', 'Pethia conchonius', 'Setipinna taty',
#        'Pethia conchonius', 'Anabas testudineus', 'Setipinna taty',
#        'Setipinna taty', 'Anabas testudineus', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Anabas testudineus', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Sillaginopsis panijus', 'Setipinna taty',
#        'Sillaginopsis panijus', 'Anabas testudineus', 'Setipinna taty',
#        'Setipinna taty', 'Sillaginopsis panijus', 'Setipinna taty',
#        'Sillaginopsis panijus', 'Anabas testudineus', 'Setipinna taty',
#        'Anabas testudineus', 'Pethia conchonius', 'Coilia dussumieri',
#        'Setipinna taty', 'Pethia conchonius', 'Setipinna taty',
#        'Sillaginopsis panijus', 'Pethia conchonius', 'Setipinna taty',
#        'Anabas testudineus', 'Sillaginopsis panijus', 'Setipinna taty',
#        'Setipinna taty', 'Coilia dussumieri', 'Setipinna taty',
#        'Sillaginopsis panijus', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Sillaginopsis panijus', 'Setipinna taty', 'Anabas testudineus',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Pethia conchonius', 'Pethia conchonius', 'Anabas testudineus',
#        'Sillaginopsis panijus', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Sillaginopsis panijus', 'Anabas testudineus',
#        'Setipinna taty', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Pethia conchonius', 'Coilia dussumieri',
#        'Setipinna taty', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Setipinna taty', 'Anabas testudineus',
#        'Setipinna taty', 'Setipinna taty', 'Anabas testudineus',
#        'Setipinna taty', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Pethia conchonius', 'Anabas testudineus', 'Setipinna taty',
#        'Setipinna taty', 'Anabas testudineus', 'Pethia conchonius',
#        'Pethia conchonius', 'Anabas testudineus', 'Sillaginopsis panijus',
#        'Pethia conchonius', 'Sillaginopsis panijus', 'Pethia conchonius',
#        'Setipinna taty', 'Sillaginopsis panijus', 'Sillaginopsis panijus',
#        'Pethia conchonius', 'Sillaginopsis panijus', 'Setipinna taty',
#        'Pethia conchonius', 'Anabas testudineus', 'Setipinna taty',
#        'Setipinna taty', 'Anabas testudineus', 'Setipinna taty',
#        'Pethia conchonius', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Anabas testudineus', 'Pethia conchonius', 'Anabas testudineus',
#        'Setipinna taty', 'Sillaginopsis panijus', 'Pethia conchonius',
#        'Setipinna taty', 'Sillaginopsis panijus', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Sillaginopsis panijus', 'Setipinna taty', 'Pethia conchonius',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Anabas testudineus', 'Anabas testudineus', 'Setipinna taty',
#        'Sillaginopsis panijus', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Sillaginopsis panijus', 'Setipinna taty',
#        'Coilia dussumieri', 'Sillaginopsis panijus', 'Coilia dussumieri',
#        'Anabas testudineus', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Pethia conchonius',
#        'Sillaginopsis panijus', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Anabas testudineus', 'Setipinna taty', 'Setipinna taty',
#        'Pethia conchonius', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Sillaginopsis panijus', 'Setipinna taty', 'Setipinna taty',
#        'Pethia conchonius', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Anabas testudineus', 'Pethia conchonius',
#        'Setipinna taty', 'Anabas testudineus', 'Anabas testudineus',
#        'Setipinna taty', 'Pethia conchonius', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Pethia conchonius',
#        'Setipinna taty', 'Setipinna taty', 'Anabas testudineus',
#        'Setipinna taty', 'Setipinna taty', 'Coilia dussumieri',
#        'Setipinna taty', 'Coilia dussumieri', 'Setipinna taty',
#        'Setipinna taty', 'Coilia dussumieri', 'Pethia conchonius',
#        'Setipinna taty', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Sillaginopsis panijus', 'Sillaginopsis panijus', 'Setipinna taty',
#        'Setipinna taty', 'Sillaginopsis panijus', 'Setipinna taty',
#        'Setipinna taty', 'Anabas testudineus', 'Setipinna taty',
#        'Sillaginopsis panijus', 'Anabas testudineus', 'Setipinna taty',
#        'Anabas testudineus', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Coilia dussumieri', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Sillaginopsis panijus', 'Setipinna taty', 'Pethia conchonius',
#        'Sillaginopsis panijus', 'Setipinna taty', 'Setipinna taty',
#        'Sillaginopsis panijus', 'Coilia dussumieri', 'Setipinna taty',
#        'Pethia conchonius', 'Setipinna taty', 'Setipinna taty',
#        'Anabas testudineus', 'Sillaginopsis panijus',
#        'Sillaginopsis panijus', 'Pethia conchonius', 'Setipinna taty',
#        'Sillaginopsis panijus', 'Sillaginopsis panijus',
#        'Coilia dussumieri', 'Pethia conchonius', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Anabas testudineus',
#        'Sillaginopsis panijus', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Pethia conchonius', 'Pethia conchonius', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Sillaginopsis panijus', 'Setipinna taty',
#        'Anabas testudineus', 'Setipinna taty', 'Setipinna taty',
#        'Anabas testudineus', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Pethia conchonius', 'Sillaginopsis panijus', 'Setipinna taty',
#        'Sillaginopsis panijus', 'Sillaginopsis panijus',
#        'Anabas testudineus', 'Coilia dussumieri', 'Pethia conchonius',
#        'Setipinna taty', 'Anabas testudineus', 'Coilia dussumieri',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Anabas testudineus', 'Anabas testudineus', 'Setipinna taty',
#        'Coilia dussumieri', 'Setipinna taty', 'Pethia conchonius',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Coilia dussumieri', 'Sillaginopsis panijus', 'Setipinna taty',
#        'Anabas testudineus', 'Anabas testudineus',
#        'Sillaginopsis panijus', 'Setipinna taty', 'Anabas testudineus',
#        'Setipinna taty', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Pethia conchonius', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Pethia conchonius', 'Coilia dussumieri',
#        'Coilia dussumieri', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Anabas testudineus', 'Anabas testudineus',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Coilia dussumieri',
#        'Sillaginopsis panijus', 'Pethia conchonius', 'Setipinna taty',
#        'Sillaginopsis panijus', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Pethia conchonius', 'Sillaginopsis panijus', 'Pethia conchonius',
#        'Anabas testudineus', 'Coilia dussumieri', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Sillaginopsis panijus', 'Coilia dussumieri', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Anabas testudineus', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Anabas testudineus', 'Sillaginopsis panijus',
#        'Coilia dussumieri', 'Anabas testudineus', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Sillaginopsis panijus', 'Setipinna taty',
#        'Setipinna taty', 'Sillaginopsis panijus', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Pethia conchonius', 'Sillaginopsis panijus',
#        'Sillaginopsis panijus', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Sillaginopsis panijus', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Pethia conchonius',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Setipinna taty', 'Pethia conchonius',
#        'Pethia conchonius', 'Setipinna taty', 'Setipinna taty',
#        'Sillaginopsis panijus', 'Setipinna taty', 'Setipinna taty',
#        'Sillaginopsis panijus', 'Sillaginopsis panijus', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Sillaginopsis panijus', 'Sillaginopsis panijus', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Anabas testudineus',
#        'Sillaginopsis panijus', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Sillaginopsis panijus', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Sillaginopsis panijus', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Setipinna taty', 'Pethia conchonius',
#        'Setipinna taty', 'Coilia dussumieri', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Pethia conchonius',
#        'Setipinna taty', 'Coilia dussumieri', 'Pethia conchonius',
#        'Setipinna taty', 'Anabas testudineus', 'Setipinna taty',
#        'Sillaginopsis panijus', 'Anabas testudineus', 'Setipinna taty',
#        'Anabas testudineus', 'Pethia conchonius', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Coilia dussumieri',
#        'Setipinna taty', 'Sillaginopsis panijus', 'Sillaginopsis panijus',
#        'Setipinna taty', 'Pethia conchonius', 'Sillaginopsis panijus',
#        'Sillaginopsis panijus', 'Pethia conchonius', 'Pethia conchonius',
#        'Anabas testudineus', 'Setipinna taty', 'Pethia conchonius',
#        'Anabas testudineus', 'Setipinna taty', 'Pethia conchonius',
#        'Pethia conchonius', 'Setipinna taty', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Setipinna taty',
#        'Anabas testudineus', 'Sillaginopsis panijus', 'Setipinna taty',
#        'Setipinna taty', 'Anabas testudineus', 'Setipinna taty',
#        'Setipinna taty', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Pethia conchonius', 'Setipinna taty', 'Sillaginopsis panijus',
#        'Anabas testudineus', 'Setipinna taty', 'Setipinna taty',
#        'Anabas testudineus'], dtype='<U22')

# %%
# Save Model Dataset Fish dan Fruit
#clf.fit(x_train_bu,y_train_bu) # Latih dataset Fruit
#fw = open('fruit_perceptron.pkl' , 'wb')
#md = pickle.dump(clf , fw)

#clf.fit(x_train_fi,y_train_fi) # Latih dataset Fish
#fw = open('fish_perceptron.pkl' , 'wb')
#md = pickle.dump(clf , fw)

# %%
akurasi=accuracy_score(pred,y_test)

print(classification_report(y_test,pred))
print("Akurasi SVM : {:.2f}%".format(akurasi*100))
# Out:
#                         precision    recall  f1-score   support
#
#     Anabas testudineus       1.00      0.74      0.85       120
#      Coilia dussumieri       1.00      0.47      0.64        77
# Otolithoides biauritus       0.00      0.00      0.00        91
#      Otolithoides pama       0.00      0.00      0.00        86
#      Pethia conchonius       0.96      1.00      0.98        89
#   Polynemus paradiseus       0.00      0.00      0.00       102
#   Puntius lateristriga       0.00      0.00      0.00        65
#         Setipinna taty       0.22      1.00      0.36       100
#  Sillaginopsis panijus       0.64      1.00      0.78        86
#
#               accuracy                           0.49       816
#              macro avg       0.42      0.47      0.40       816
#           weighted avg       0.44      0.49      0.42       816
#
# Akurasi SVM : 49.02%
# C:\Users\ALIF RAMA\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\ALIF RAMA\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# C:\Users\ALIF RAMA\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\sklearn\metrics\_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
new_data={'Area': [68321, 83537],
          'Perimeter' : [1140.811, 1329.710],
          'Major_Axis_Length' : [781.082, 511.1513],
          'Minor_Axis_Length' : [381.774, 204.4367],
          'Convex_Area' : [77819, 84381],
          'Equiv_Diameter' : [517.926, 298.4289],
          'Eccentricity' : [0.630, 0.9840],
          'Solidity' : [0.9516, 0.9907],
          'Extent' : [0.9153, 0.5798],
          'Roundness' : [0.8416, 0.5972],
          'Aspect_Ration' : [3.7810, 2.5996],
          'Compactness' : [0.7612, 0.5973]}


new_data =pd.DataFrame(new_data)
new_data
# Out:
#     Area  Perimeter  Major_Axis_Length  Minor_Axis_Length  Convex_Area  \
# 0  68321   1140.811           781.0820           381.7740        77819
# 1  83537   1329.710           511.1513           204.4367        84381
#
#    Equiv_Diameter  Eccentricity  Solidity  Extent  Roundness  Aspect_Ration  \
# 0        517.9260         0.630    0.9516  0.9153     0.8416         3.7810
# 1        298.4289         0.984    0.9907  0.5798     0.5972         2.5996
#
#    Compactness
# 0       0.7612
# 1       0.5973

# %%
clf.fit(x_train,y_train)
pred = clf.predict(new_data)
pred
# Out:
# array(['Çerçevelik', 'Ürgüp Sivrisi'], dtype='<U13')

# %%
opf = open('pumpkin_perceptron.pkl' , 'rb')
model = pickle.load(opf)
y_pred_model = model.predict(new_data)

print("Hasil Prediksi dari model : ",y_pred_model)
# Out:
# Hasil Prediksi dari model :  ['Çerçevelik' 'Ürgüp Sivrisi']
